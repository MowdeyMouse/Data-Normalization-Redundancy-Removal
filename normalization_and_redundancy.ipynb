# %% [markdown]
# #imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\maadh\Downloads\hotel_bookings.csv.zip')
df.fillna(0, inplace=True)

# %%
sns.distplot(df['adults'])
# Out:
# C:\Users\maadh\AppData\Local\Temp\ipykernel_14376\2474689616.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['adults'])
# <Axes: xlabel='adults', ylabel='Density'>

# %%
sns.boxplot(x = 'adults', y = 'stays_in_weekend_nights', data = df)
# Out:
# <Axes: xlabel='adults', ylabel='stays_in_weekend_nights'>

# %%
sns.boxplot(y = 'stays_in_weekend_nights', data = df)
# Out:
# <Axes: ylabel='stays_in_weekend_nights'>

# %%
df['stays_in_weekend_nights'].mean()
# Out:
# 0.9275986263506156

# %%
df1 = df[df['stays_in_weekend_nights'] < 5.0]

# %%
sns.boxplot(y = 'stays_in_weekend_nights', data = df1)
# Out:
# <Axes: ylabel='stays_in_weekend_nights'>

# %%
df1['stays_in_weekend_nights'].mean()
# Out:
# 0.9108999882398401

# %%
sns.boxplot(x = 'adults', y = 'stays_in_weekend_nights', data = df1 )
# Out:
# <Axes: xlabel='adults', ylabel='stays_in_weekend_nights'>
